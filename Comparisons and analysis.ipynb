# %%
# import thr necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df1 =  pd.read_csv('/content/score list.csv')

# %%
ss1 =  pd.read_csv('/content/IEMOCAP_Dataset.csv') 
ss2 =  pd.read_csv('/content/MELD_Dataset.csv')

# %%
ss1
# Out:
#      Architecture  learning rate Regularisation  regularisation  \
# 0    COSMIC  (OG)         0.0001             L2          0.0003
# 1    COSMIC  (OG)         0.0001             L2          0.0003
# 2    COSMIC  (OG)         0.0001             L2          0.0003
# 3    COSMIC  (OG)         0.0010             L2          0.0030
# 4    COSMIC  (OG)         0.0010             L2          0.0030
# ..            ...            ...            ...             ...
# 67  bc-LSTM  (OG)         0.0010             L2          0.0001
# 68  bc-LSTM  (OG)         0.0010             L2          0.0001
# 69  bc-LSTM  (OG)         0.0010             L2          0.0001
# 70  bc-LSTM  (OG)         0.0010             L2          0.0001
# 71  bc-LSTM  (OG)         0.0010             L2          0.0001
#
#     rec dropout rate  dropout rate  batch size  epoch Optimiser  \
# 0                0.1          0.25          10     10      Adam
# 1                0.1          0.25          10     10       SGD
# ...

# %%
ss2
# Out:
#          Architecture  learning rate Regularisation  regularisation  \
# 0       bc-LSTM  (OG)         0.0001             L1         0.00001
# 1       bc-LSTM  (OG)         0.0001             L2         0.00001
# 2       bc-LSTM  (OG)         0.0001             L2         0.00001
# 3       bc-LSTM  (OG)         0.0001             L1         0.00001
# 4       bc-LSTM  (OG)         0.0001             L1         0.00001
# ..                ...            ...            ...             ...
# 61  Dialogu RNN  (OG)         0.0001             L2         0.00001
# 62  Dialogu RNN  (OG)         0.0001             L2         0.00001
# 63  Dialogu RNN  (OG)         0.0001             L2         0.00001
# 64  Dialogu RNN  (OG)         0.0001             L1         0.00001
# 65  Dialogu RNN  (OG)         0.0001             L1         0.00001
#
#     rec dropout rate  dropout rate  batch size  epoch Optimiser  \
# 0                0.1          0.25          10     10      Adam
# ...

# %% [markdown]
# 1. on which optimizer is a particular model on average performing better?
# 2. effect of L1 & L2 , along with numerical value of regularization
# 3. effect of dropout rate and changes
# 4. effect of batch_size and epochs runned because of learning rate
# 5. best hyperparameters loaded model after comparison
# 6. na, maximum, minimum, outliers
# Q questions while comparing different models on dataset 1
# Q same questions results with dataset 2
#
# // is there any difference in answers of different dataset, if yes then why?

# %% [markdown]
# ### MELD_Dataset analysis

# %% [markdown]
# #### 1 on which optimizer is a particular model on average performing better?

# %%
optimizer_search = ss1[['Architecture','Optimiser', 'test accuracy','train accuracy']]

# %%
optimizer_search_2 = ss2[['Architecture','Optimiser', 'test accuracy','train accuracy']]

# %%
optimizer_search
# Out:
#      Architecture Optimiser  test accuracy  train accuracy
# 0    COSMIC  (OG)      Adam          62.72           59.52
# 1    COSMIC  (OG)       SGD          21.38           20.84
# 2    COSMIC  (OG)   RMSprop          63.03           63.80
# 3    COSMIC  (OG)      Adam          63.59           65.11
# 4    COSMIC  (OG)       SGD          24.95           26.23
# ..            ...       ...            ...             ...
# 67  bc-LSTM  (OG)       SGD          23.54           24.29
# 68  bc-LSTM  (OG)   RMSprop          56.81           98.38
# 69  bc-LSTM  (OG)      Adam          60.32           98.42
# 70  bc-LSTM  (OG)       SGD          24.71           25.39
# 71  bc-LSTM  (OG)   RMSprop          57.18           98.78
#
# [72 rows x 4 columns]

# %%
plt.figure(figsize=(12, 9))
df_heatmap = optimizer_search.pivot_table(values='test accuracy',index='Optimiser',columns='Architecture',aggfunc=np.mean)
sns.heatmap(df_heatmap,annot=False,cmap="YlGnBu")
plt.title('iemocap_dataset')
plt.show()

# %%
plt.figure(figsize=(12, 9))
df_heatmap = optimizer_search_2.pivot_table(values='test accuracy',index='Optimiser',columns='Architecture',aggfunc=np.mean)
sns.heatmap(df_heatmap,annot=False,cmap="YlGnBu")
plt.title('MELD_dataset')
plt.show()

# %% [markdown]
# #### 2. effect of L1 & L2 , along with numerical value of regularization
#
# - take columns of L1 L2 REGULARIZTAION AND OVERFITTING SCORE, SORT BY REG, TAKE AVERAGE OF OVERFITTING SCORE PRODUCE A HEAT MAP OF COMPARISON MAP

# %%
fitting = ss1[['Architecture','Regularisation', 'regularisation','overfitting_score']]

# %%
fitting_2 = ss2[['Architecture','Regularisation', 'regularisation','overfitting_score']]

# %%
L1_MELD = fitting_2[ fitting_2.Regularisation == 'L1']

# %%
L1_IEM = fitting[ fitting.Regularisation == 'L1']

# %%
# Using GroupBy multiple column
PL1_MELD =L1_MELD.groupby(['Architecture','regularisation'])['overfitting_score'].sum()
print(PL1_MELD)
# Out:
# Architecture       regularisation
# COSMIC  (OG)       0.00001           40.41
# Dialogu RNN  (OG)  0.00001           10.11
# bc-LSTM  (OG)      0.00001           13.39
# Name: overfitting_score, dtype: float64

# %%
plt_L1_MELD = pd.DataFrame(PL1_MELD)
plt_L1_MELD.reset_index(inplace=True)
plt_L1_MELD
# Out:
#         Architecture  regularisation  overfitting_score
# 0       COSMIC  (OG)         0.00001              40.41
# 1  Dialogu RNN  (OG)         0.00001              10.11
# 2      bc-LSTM  (OG)         0.00001              13.39

# %%
fig = px.bar(plt_L1_MELD, y="regularisation", x='overfitting_score',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Using GroupBy multiple column
PL1_IEM = L1_IEM.groupby(['Architecture','regularisation'])['overfitting_score'].sum()
print(PL1_IEM)
# Out:
# Architecture       regularisation
# COSMIC  (OG)       0.00001            4.590
#                    0.00030           -4.070
# Dialogu RNN  (OG)  0.00001           61.803
# bc-LSTM  (OG)      0.00001           45.850
# Name: overfitting_score, dtype: float64

# %%
plt_L1_IEM = pd.DataFrame(PL1_IEM)
plt_L1_IEM.reset_index(inplace=True)
plt_L1_IEM
# Out:
#         Architecture  regularisation  overfitting_score
# 0       COSMIC  (OG)         0.00001              4.590
# 1       COSMIC  (OG)         0.00030             -4.070
# 2  Dialogu RNN  (OG)         0.00001             61.803
# 3      bc-LSTM  (OG)         0.00001             45.850

# %%
fig = px.bar(plt_L1_IEM, y="regularisation", x='overfitting_score',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
L2_MELD = fitting_2[ fitting_2.Regularisation == 'L2']
#L2_MELD

# %%
L2_IEM = fitting[ fitting.Regularisation == 'L2']
#L2_IEM

# %%
# Using GroupBy multiple column
PL2_MELD =L2_MELD.groupby(['Architecture','regularisation'])['overfitting_score'].sum()
print(PL2_MELD)
# Out:
# Architecture       regularisation
# COSMIC  (OG)       0.00030            46.73
#                    0.00300           161.60
#                    0.03000            -0.28
# Dialogu RNN  (OG)  0.00001            19.93
#                    0.00100            19.46
# bc-LSTM  (OG)      0.00001            38.60
#                    0.00010            75.59
#                    0.01000           -13.08
# Name: overfitting_score, dtype: float64

# %%
plt_L2_MELD = pd.DataFrame(PL2_MELD)
plt_L2_MELD.reset_index(inplace=True)
plt_L2_MELD
# Out:
#         Architecture  regularisation  overfitting_score
# 0       COSMIC  (OG)         0.00030              46.73
# 1       COSMIC  (OG)         0.00300             161.60
# 2       COSMIC  (OG)         0.03000              -0.28
# 3  Dialogu RNN  (OG)         0.00001              19.93
# 4  Dialogu RNN  (OG)         0.00100              19.46
# 5      bc-LSTM  (OG)         0.00001              38.60
# 6      bc-LSTM  (OG)         0.00010              75.59
# 7      bc-LSTM  (OG)         0.01000             -13.08

# %%
fig = px.bar(plt_L2_MELD, y="regularisation", x='overfitting_score',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.update_traces(width=7)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Using GroupBy multiple column
PL2_IEM = L2_IEM.groupby(['Architecture','regularisation'])['overfitting_score'].sum()
print(PL2_IEM)
# Out:
# Architecture       regularisation
# COSMIC  (OG)       0.00030            -2.9700
#                    0.00300           -31.4369
#                    0.03000            -3.7000
# Dialogu RNN  (OG)  0.00001           307.3400
#                    0.00100             7.2000
# bc-LSTM  (OG)      0.00001           214.2948
#                    0.00010           417.9293
#                    0.01000            67.9500
# Name: overfitting_score, dtype: float64

# %%
plt_L2_IEM = pd.DataFrame(PL2_IEM)
plt_L2_IEM.reset_index(inplace=True)
plt_L2_IEM
# Out:
#         Architecture  regularisation  overfitting_score
# 0       COSMIC  (OG)         0.00030            -2.9700
# 1       COSMIC  (OG)         0.00300           -31.4369
# 2       COSMIC  (OG)         0.03000            -3.7000
# 3  Dialogu RNN  (OG)         0.00001           307.3400
# 4  Dialogu RNN  (OG)         0.00100             7.2000
# 5      bc-LSTM  (OG)         0.00001           214.2948
# 6      bc-LSTM  (OG)         0.00010           417.9293
# 7      bc-LSTM  (OG)         0.01000            67.9500

# %%
fig = px.bar(plt_L2_IEM, y="regularisation", x='overfitting_score',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.update_traces(width=7)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### batch size, epoch, lr

# %%
epoch_learning = ss1[['Architecture','Optimiser', 'batch size','epoch','learning rate','test accuracy'  ]]

# %%
batch_IEM = epoch_learning.groupby(['Architecture','batch size'])['test accuracy'].mean()

# %%
batch_IEM = epoch_learning.groupby(['Architecture','batch size','learning rate'])['test accuracy'].mean()
batch_IEM
# Out:
# Architecture       batch size  learning rate
# COSMIC  (OG)       10          0.0001           49.195556
#                                0.0010           49.874444
#                                0.0100           28.180000
#                    15          0.0010           49.868333
# Dialogu RNN  (OG)  10          0.0001           47.473917
#                                0.0100           26.530000
#                    15          0.0001           46.651667
# bc-LSTM  (OG)      10          0.0001           44.738889
#                                0.0010           46.448333
#                                0.1000           50.393333
#                    15          0.0010           47.485000
# Name: test accuracy, dtype: float64

# %%
batch_IEM_plot = pd.DataFrame(batch_IEM)
batch_IEM_plot.reset_index(inplace=True)
batch_IEM_plot
# Out:
#          Architecture  batch size  learning rate  test accuracy
# 0        COSMIC  (OG)          10         0.0001      49.195556
# 1        COSMIC  (OG)          10         0.0010      49.874444
# 2        COSMIC  (OG)          10         0.0100      28.180000
# 3        COSMIC  (OG)          15         0.0010      49.868333
# 4   Dialogu RNN  (OG)          10         0.0001      47.473917
# 5   Dialogu RNN  (OG)          10         0.0100      26.530000
# 6   Dialogu RNN  (OG)          15         0.0001      46.651667
# 7       bc-LSTM  (OG)          10         0.0001      44.738889
# 8       bc-LSTM  (OG)          10         0.0010      46.448333
# 9       bc-LSTM  (OG)          10         0.1000      50.393333
# 10      bc-LSTM  (OG)          15         0.0010      47.485000

# %%
fig = px.bar(batch_IEM_plot, y="batch size", x='test accuracy',
             hover_data=['learning rate'], color='Architecture',
             labels={'pop':'population of Canada'}, height=550, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(batch_IEM_plot, y="batch size", x='test accuracy',
             hover_data=['Architecture', 'learning rate'], color='Architecture',
             labels={'pop':'population of Canada'}, height=400, width=600)
fig.update_traces(width=0.8)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(batch_IEM_plot, y="batch size", x='test accuracy',
             hover_data=['Architecture', 'learning rate'], color='learning rate',
             labels={'pop':'population of Canada'}, height=400, width=600)
fig.update_traces(width=0.8)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
batch_IEM
# Out:
# Architecture       batch size
# COSMIC  (OG)       10            46.484286
#                    15            49.868333
# Dialogu RNN  (OG)  10            43.285133
#                    15            46.651667
# bc-LSTM  (OG)      10            46.251111
#                    15            47.485000
# Name: test accuracy, dtype: float64

# %%
batch_IEM_plot = pd.DataFrame(batch_IEM)
batch_IEM_plot.reset_index(inplace=True)
batch_IEM_plot
# Out:
#         Architecture  batch size  test accuracy
# 0       COSMIC  (OG)          10      46.484286
# 1       COSMIC  (OG)          15      49.868333
# 2  Dialogu RNN  (OG)          10      43.285133
# 3  Dialogu RNN  (OG)          15      46.651667
# 4      bc-LSTM  (OG)          10      46.251111
# 5      bc-LSTM  (OG)          15      47.485000

# %%
fig = px.bar(batch_meld_plot, y="batch size", x='test accuracy',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
batch_meld = ss2.groupby(['Architecture','batch size','learning rate'])['test accuracy'].mean()
batch_meld
# Out:
# Architecture       batch size  learning rate
# COSMIC  (OG)       10          0.0001           59.763333
#                                0.0010           59.531111
#                                0.0100           55.376667
#                    15          0.0010           60.076667
# Dialogu RNN  (OG)  10          0.0001           54.991667
#                                0.0100           54.596667
#                    15          0.0001           52.738333
# bc-LSTM  (OG)      10          0.0001           47.888889
#                                0.0010           54.993333
#                                0.1000           52.023333
#                    15          0.0010           55.306667
# Name: test accuracy, dtype: float64

# %%
batch_meld_plot = pd.DataFrame(batch_meld)
batch_meld_plot.reset_index(inplace=True)
batch_meld_plot
# Out:
#          Architecture  batch size  learning rate  test accuracy
# 0        COSMIC  (OG)          10         0.0001      59.763333
# 1        COSMIC  (OG)          10         0.0010      59.531111
# 2        COSMIC  (OG)          10         0.0100      55.376667
# 3        COSMIC  (OG)          15         0.0010      60.076667
# 4   Dialogu RNN  (OG)          10         0.0001      54.991667
# 5   Dialogu RNN  (OG)          10         0.0100      54.596667
# 6   Dialogu RNN  (OG)          15         0.0001      52.738333
# 7       bc-LSTM  (OG)          10         0.0001      47.888889
# 8       bc-LSTM  (OG)          10         0.0010      54.993333
# 9       bc-LSTM  (OG)          10         0.1000      52.023333
# 10      bc-LSTM  (OG)          15         0.0010      55.306667

# %%
fig = px.bar(batch_meld_plot, y="batch size", x='test accuracy',
             hover_data=['Architecture', 'learning rate'], color='learning rate',
             labels={'pop':'population of Canada'}, height=400, width=600)
fig.update_traces(width=0.8)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(batch_meld_plot, y="batch size", x='test accuracy',
             hover_data=['Architecture', 'learning rate'], color='Architecture',
             labels={'pop':'population of Canada'}, height=400, width=600)
fig.update_traces(width=0.8)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(batch_meld_plot, y="batch size", x='test accuracy',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
epoch_IEM = epoch_learning.groupby(['Architecture','epoch'])['test accuracy'].mean()
epoch_IEM
# Out:
# Architecture       epoch
# COSMIC  (OG)       10       46.587143
#                    15       49.508333
# Dialogu RNN  (OG)  10       42.361133
#                    15       48.961667
# bc-LSTM  (OG)      10       46.333333
#                    15       47.238333
# Name: test accuracy, dtype: float64

# %%
epoch_IEM = epoch_learning.groupby(['Architecture','epoch', 'learning rate'])['test accuracy'].mean()
epoch_IEM
# Out:
# Architecture       epoch  learning rate
# COSMIC  (OG)       10     0.0001           49.195556
#                           0.0010           50.114444
#                           0.0100           28.180000
#                    15     0.0010           49.508333
# Dialogu RNN  (OG)  10     0.0001           46.318917
#                           0.0100           26.530000
#                    15     0.0001           48.961667
# bc-LSTM  (OG)      10     0.0001           44.738889
#                           0.0010           46.695000
#                           0.1000           50.393333
#                    15     0.0010           47.238333
# Name: test accuracy, dtype: float64

# %%
epoch_IEM_plot = pd.DataFrame(epoch_IEM)
epoch_IEM_plot.reset_index(inplace=True)
epoch_IEM_plot
# Out:
#          Architecture  epoch  learning rate  test accuracy
# 0        COSMIC  (OG)     10         0.0001      49.195556
# 1        COSMIC  (OG)     10         0.0010      50.114444
# 2        COSMIC  (OG)     10         0.0100      28.180000
# 3        COSMIC  (OG)     15         0.0010      49.508333
# 4   Dialogu RNN  (OG)     10         0.0001      46.318917
# 5   Dialogu RNN  (OG)     10         0.0100      26.530000
# 6   Dialogu RNN  (OG)     15         0.0001      48.961667
# 7       bc-LSTM  (OG)     10         0.0001      44.738889
# 8       bc-LSTM  (OG)     10         0.0010      46.695000
# 9       bc-LSTM  (OG)     10         0.1000      50.393333
# 10      bc-LSTM  (OG)     15         0.0010      47.238333

# %%
fig = px.scatter(epoch_IEM_plot, y="epoch", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(epoch_IEM_plot, y="learning rate", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
epoch_IEM_plot = pd.DataFrame(epoch_IEM)
epoch_IEM_plot.reset_index(inplace=True)
epoch_IEM_plot
# Out:
#         Architecture  epoch  test accuracy
# 0       COSMIC  (OG)     10      46.587143
# 1       COSMIC  (OG)     15      49.508333
# 2  Dialogu RNN  (OG)     10      42.361133
# 3  Dialogu RNN  (OG)     15      48.961667
# 4      bc-LSTM  (OG)     10      46.333333
# 5      bc-LSTM  (OG)     15      47.238333

# %%
fig = px.scatter(epoch_IEM_plot, y="epoch", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
epoch_meld = ss2.groupby(['Architecture','epoch'])['test accuracy'].mean()
epoch_meld
# Out:
# Architecture       epoch
# COSMIC  (OG)       10       58.832000
#                    15       59.706667
# Dialogu RNN  (OG)  10       53.837333
#                    15       55.426667
# bc-LSTM  (OG)      10       50.916111
#                    15       55.396667
# Name: test accuracy, dtype: float64

# %%
epoch_meld = ss2.groupby(['Architecture','epoch','learning rate'])['test accuracy'].mean()
epoch_meld
# Out:
# Architecture       epoch  learning rate
# COSMIC  (OG)       10     0.0001           59.763333
#                           0.0010           59.628333
#                           0.0100           55.376667
#                    15     0.0010           59.706667
# Dialogu RNN  (OG)  10     0.0001           53.647500
#                           0.0100           54.596667
#                    15     0.0001           55.426667
# bc-LSTM  (OG)      10     0.0001           47.888889
#                           0.0010           54.903333
#                           0.1000           52.023333
#                    15     0.0010           55.396667
# Name: test accuracy, dtype: float64

# %%
epoch_meld_plot = pd.DataFrame(epoch_meld)
epoch_meld_plot.reset_index(inplace=True)
epoch_meld_plot
# Out:
#          Architecture  epoch  learning rate  test accuracy
# 0        COSMIC  (OG)     10         0.0001      59.763333
# 1        COSMIC  (OG)     10         0.0010      59.628333
# 2        COSMIC  (OG)     10         0.0100      55.376667
# 3        COSMIC  (OG)     15         0.0010      59.706667
# 4   Dialogu RNN  (OG)     10         0.0001      53.647500
# 5   Dialogu RNN  (OG)     10         0.0100      54.596667
# 6   Dialogu RNN  (OG)     15         0.0001      55.426667
# 7       bc-LSTM  (OG)     10         0.0001      47.888889
# 8       bc-LSTM  (OG)     10         0.0010      54.903333
# 9       bc-LSTM  (OG)     10         0.1000      52.023333
# 10      bc-LSTM  (OG)     15         0.0010      55.396667

# %%
fig = px.scatter(epoch_meld_plot, y="epoch", x='test accuracy', color="Architecture",size='test accuracy')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(epoch_meld_plot, y="learning rate", x='test accuracy', color="Architecture",size='test accuracy')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
epoch_meld_plot = pd.DataFrame(epoch_meld)
epoch_meld_plot.reset_index(inplace=True)
epoch_meld_plot
# Out:
#         Architecture  epoch  test accuracy
# 0       COSMIC  (OG)     10      58.832000
# 1       COSMIC  (OG)     15      59.706667
# 2  Dialogu RNN  (OG)     10      53.837333
# 3  Dialogu RNN  (OG)     15      55.426667
# 4      bc-LSTM  (OG)     10      50.916111
# 5      bc-LSTM  (OG)     15      55.396667

# %%
fig = px.bar(epoch_meld_plot, y="epoch", x='test accuracy',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(epoch_meld_plot, y="epoch", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lr_IEM = epoch_learning.groupby(['Architecture','learning rate'])['test accuracy'].mean()
lr_IEM
# Out:
# Architecture       learning rate
# COSMIC  (OG)       0.0001           49.195556
#                    0.0010           49.872000
#                    0.0100           28.180000
# Dialogu RNN  (OG)  0.0001           47.199833
#                    0.0100           26.530000
# bc-LSTM  (OG)      0.0001           44.738889
#                    0.0010           46.966667
#                    0.1000           50.393333
# Name: test accuracy, dtype: float64

# %%
lr_IEM_plot = pd.DataFrame(lr_IEM)
lr_IEM_plot.reset_index(inplace=True)
lr_IEM_plot
# Out:
#         Architecture  learning rate  test accuracy
# 0       COSMIC  (OG)         0.0001      49.195556
# 1       COSMIC  (OG)         0.0010      49.872000
# 2       COSMIC  (OG)         0.0100      28.180000
# 3  Dialogu RNN  (OG)         0.0001      47.199833
# 4  Dialogu RNN  (OG)         0.0100      26.530000
# 5      bc-LSTM  (OG)         0.0001      44.738889
# 6      bc-LSTM  (OG)         0.0010      46.966667
# 7      bc-LSTM  (OG)         0.1000      50.393333

# %%
fig = px.scatter(lr_IEM_plot, y="learning rate", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lr_meld = ss2.groupby(['Architecture','learning rate'])['test accuracy'].mean()
lr_meld
# Out:
# Architecture       learning rate
# COSMIC  (OG)       0.0001           59.763333
#                    0.0010           59.667500
#                    0.0100           55.376667
# Dialogu RNN  (OG)  0.0001           54.240556
#                    0.0100           54.596667
# bc-LSTM  (OG)      0.0001           47.888889
#                    0.0010           55.150000
#                    0.1000           52.023333
# Name: test accuracy, dtype: float64

# %%
lr_meld_plot = pd.DataFrame(lr_meld)
lr_meld_plot.reset_index(inplace=True)
lr_meld_plot
# Out:
#         Architecture  learning rate  test accuracy
# 0       COSMIC  (OG)         0.0001      59.763333
# 1       COSMIC  (OG)         0.0010      59.667500
# 2       COSMIC  (OG)         0.0100      55.376667
# 3  Dialogu RNN  (OG)         0.0001      54.240556
# 4  Dialogu RNN  (OG)         0.0100      54.596667
# 5      bc-LSTM  (OG)         0.0001      47.888889
# 6      bc-LSTM  (OG)         0.0010      55.150000
# 7      bc-LSTM  (OG)         0.1000      52.023333

# %%
fig = px.scatter(lr_meld_plot, y="learning rate", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
DR_IEM = ss1.groupby(['Architecture','dropout rate'])['test accuracy'].mean()
DR_IEM
# Out:
# Architecture       dropout rate
# COSMIC  (OG)       0.25            45.451333
#                    0.50            49.467500
# Dialogu RNN  (OG)  0.10            36.170000
#                    0.25            47.477800
# bc-LSTM  (OG)      0.25            47.123333
#                    0.50            42.613333
# Name: test accuracy, dtype: float64

# %%
DR_IEM_plot = pd.DataFrame(DR_IEM)
DR_IEM_plot.reset_index(inplace=True)
DR_IEM_plot
# Out:
#         Architecture  dropout rate  test accuracy
# 0       COSMIC  (OG)          0.25      45.451333
# 1       COSMIC  (OG)          0.50      49.467500
# 2  Dialogu RNN  (OG)          0.10      36.170000
# 3  Dialogu RNN  (OG)          0.25      47.477800
# 4      bc-LSTM  (OG)          0.25      47.123333
# 5      bc-LSTM  (OG)          0.50      42.613333

# %%
import plotly.express as px

#df = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(DR_IEM_plot, y="dropout rate", x='test accuracy',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
#df = px.data.tips()

fig = px.scatter(DR_IEM_plot, y="dropout rate", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
DR_meld = ss2.groupby(['Architecture','dropout rate'])['test accuracy'].mean()
DR_meld
# Out:
# Architecture       dropout rate
# COSMIC  (OG)       0.25            58.271111
#                    0.50            59.690000
# Dialogu RNN  (OG)  0.10            54.775000
#                    0.25            54.098000
# bc-LSTM  (OG)      0.25            52.971429
#                    0.50            45.490000
# Name: test accuracy, dtype: float64

# %%
DR_meld_plot = pd.DataFrame(DR_meld)
DR_meld_plot.reset_index(inplace=True)
DR_meld_plot
# Out:
#         Architecture  dropout rate  test accuracy
# 0       COSMIC  (OG)          0.25      58.271111
# 1       COSMIC  (OG)          0.50      59.690000
# 2  Dialogu RNN  (OG)          0.10      54.775000
# 3  Dialogu RNN  (OG)          0.25      54.098000
# 4      bc-LSTM  (OG)          0.25      52.971429
# 5      bc-LSTM  (OG)          0.50      45.490000

# %%
import plotly.express as px

#df = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(DR_meld_plot, y="dropout rate", x='test accuracy',
             hover_data=['Architecture'], color='Architecture',
             labels={'pop':'population of Canada'}, height=350, width =700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
#df = px.data.tips()

fig = px.scatter(DR_meld_plot, y="dropout rate", x='test accuracy', color="Architecture",size='test accuracy')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
